# %%
# Importing default Libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
import datetime
import os


pd.options.display.max_rows = 1000
pd.options.display.max_columns = 1000

# Hi-resolution Plots and Matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# Set the maximum number of rows and columns to be displayed
warnings.filterwarnings("ignore")

# "magic commands" to enable autoreload of your imported packages
# %load_ext autoreload
# %autoreload 2

# %%
data = pd.read_csv(
    "/Users/janduplessis/code/janduplessis883/jan-notebooks/data/immsNEW.csv"
)

# %%
data.head()
# Out:
#    ImmunizeMe - All Pts: Patient ID  ImmunizeMe - vaccines: Patient ID  \
# 0                            567215                           567215.0
# 1                           2663484                          2663484.0
# 2                           2723897                          2723897.0
# 3                           2723897                          2723897.0
# 4                           2466415                          2466415.0
#
#    Age in years Date of birth First name  NHS number     Sex  \
# 0            43   20-Aug-1981      Habib  4087071049    Male
# 1            42   08-Feb-1982    Timothy  4264132851    Male
# 2            27   15-Jun-1997     Jemima  6348907287  Female
# 3            27   15-Jun-1997     Jemima  6348907287  Female
# 4            23   22-Sep-2000     Kieran  6420193850    Male
#
#              Surname  Deduction date Registration date  \
# 0             Sattar             NaN       20-Sep-2018
# 1            Nichols             NaN       11-Apr-2012
# ...

# %%
from function import *


def loadcsv(df):

    df.columns = [
        "Patient ID1",
        "Patient ID2",
        "Age",
        "dob",
        "First name",
        "NHS",
        "Sex",
        "Surname",
        "Deduction date",
        "Registration date",
        "Vaccination type",
        "telephone",
        "Event date",
        "Event done at ID",
        "Patient Count",
    ]
    df = prep_df(df)

    df = calculate_age_at_vaccination(df, "dob", "event_date")
    return df

# %%
df = loadcsv(data)

# %%
influenza_df = influezenza_stats_df(df)

# %%
influenza_df.head(2)
# Out:
#        patient_id1  patient_id2  age        dob first_name         nhs   sex  \
# 15061     59416030   59416030.0    3 2021-01-28      Luigi  7255214215  Male
# 16477     58100817   58100817.0    4 2019-10-12      Renzo  7220689381  Male
#
#                   surname deduction_date registration_date vaccination_type  \
# 15061  Bocchino Collantes            NaT        2021-04-21        Influenza
# 16477   De Simone Jozwiak            NaT        2024-06-24        Influenza
#
#           telephone event_date event_done_at_id  patient_count  age_years  \
# 15061  07492 512501 2023-10-19           E87750              1          3
# 16477  07557 989428 2022-12-13        Elsewhere              1          4
#
#        age_months  age_weeks  age_at_vaccination
# 15061          43        190                 2.0
# 16477          59        258                 3.0

# %%
influenza_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3458 entries, 15061 to 6276
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   patient_id1         3458 non-null   int64
#  1   patient_id2         3458 non-null   float64
#  2   age                 3458 non-null   int64
#  3   dob                 3458 non-null   datetime64[ns]
#  4   first_name          3458 non-null   object
#  5   nhs                 3458 non-null   object
#  6   sex                 3458 non-null   object
#  7   surname             3458 non-null   object
#  8   deduction_date      0 non-null      datetime64[ns]
#  9   registration_date   3458 non-null   datetime64[ns]
#  10  vaccination_type    3458 non-null   object
#  11  telephone           3287 non-null   object
#  12  event_date          3458 non-null   datetime64[ns]
#  13  event_done_at_id    3458 non-null   object
#  14  patient_count       3458 non-null   int64
# ...

# %%
ts = to_timeseries(influenza_df, "event_date")

# %%
ts
# Out:
#           date  count
# 298 2018-08-31      0
# 299 2018-09-30     26
# 300 2018-10-31     59
# 301 2018-11-30     17
# 302 2018-12-31      9
# 303 2019-01-31      8
# 304 2019-02-28      3
# 305 2019-03-31      0
# 306 2019-04-30      0
# 307 2019-05-31      0
# 308 2019-06-30      0
# 309 2019-07-31      0
# 310 2019-08-31      1
# 311 2019-09-30     13
# 312 2019-10-31     63
# 313 2019-11-30     30
# 314 2019-12-31     24
# 315 2020-01-31      4
# 316 2020-02-29      3
# 317 2020-03-31      2
# 318 2020-04-30      0
# 319 2020-05-31      0
# 320 2020-06-30      0
# 321 2020-07-31      0
# 322 2020-08-31      0
# 323 2020-09-30      1
# 324 2020-10-31     93
# 325 2020-11-30     27
# 326 2020-12-31     49
# 327 2021-01-31      3
# 328 2021-02-28      0
# 329 2021-03-31      0
# 330 2021-04-30      0
# 331 2021-05-31      0
# 332 2021-06-30      0
# 333 2021-07-31      0
# 334 2021-08-31      0
# 335 2021-09-30      4
# 336 2021-10-31     16
# 337 2021-11-30      5
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates

# Assuming 'ts' is a DataFrame with a 'date' column in datetime format
fig, ax = plt.subplots(figsize=(20, 6))
# Create the bar plot
sns.barplot(x="date", y="count", data=ts)
ax.yaxis.grid(True, linestyle="--", linewidth=0.5, color="#888888")
ax.xaxis.grid(False)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)

# Rotate x-ticks for better visibility if needed
plt.xticks(rotation=90)
plt.tight_layout()
# Display the plot
plt.show()
